# %%
from plastic_neuron import PlasticNeuron
from abstract_neuron import AbstractNeuron
import matplotlib.pyplot as plt
from neuron_plots import NeuronPlots
from neuron_utils import NeuronUtils

# %% [markdown]
# # Submerging the neuron in a uniform oscillating external electric field

# %%
neuron = PlasticNeuron(
    n_synapses = 10,
    generate_stimulus = NeuronUtils.create_no_stimulus
)

neuron.synapse_info
# Out:
# Creating cell
# 	1
# 	1
# 	0
# 23
# After any change to cell geometry or nseg, be sure to invoke setpointers()
# Generating synapse information
# Inserting 10 synapses
#    Dendrite  Location    Distance  Delay  Conductance  InitialWeight
# 0        14  0.139538  116.315870      0      0.00005              0
# 1         6  0.676699  119.467511      0      0.00005              0
# 2        27  0.031783  214.478018      0      0.00005              0
# 3         5  0.218638  125.874136      0      0.00005              0
# 4        26  0.220441  237.214368      0      0.00005              0
# 5        37  0.278191  286.953628      0      0.00005              0
# 6        21  0.277871  179.285582      0      0.00005              0
# 7        13  0.957213  199.340123      0      0.00005              0
# 8        21  0.102210  153.333687      0      0.00005              0
# 9        24  0.096716  191.699553      0      0.00005              0

# %%
NeuronUtils.set_field(
    theta_deg = 90,
    phi_deg = 90
)

NeuronUtils.set_stimulus(
    delay = 0,
    frequency1 = 5,
    frequency2 = 0,
    amplitude = 35,
    duration = 1000,
    phase = 0
)

neuron.run(duration = 500)
# Out:
# Neuron initialized
# Elapsed time: 11.82 seconds

# %%
NeuronPlots.plot_soma_voltage(neuron)

# %%
NeuronPlots.plot_all_synapses(neuron)
