# %%
import glob
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec

import os
while not os.path.isdir('.git'):
    os.chdir('../..')

import matplotlib as mpl
mpl.rcParams["font.family"] = "Avenir"

fig_width = 11.27

# %% [markdown]
# # LTP protocol

# %%
test_stimulus_1 = 100
test_stimulus_2 = 2500

ltp_frequency = 50
ltp_start = 1000
ltp_duration = 1000

# %%
def generate_ltp_spike_times():
    """Generate Poisson-distributed spike times."""
    spikes = []
    t = test_stimulus_1 + int(1000 / ltp_frequency)
    spikes.append(t)

    t = ltp_start
    while t <= ltp_start + ltp_duration:
        spikes.append(t)
        isi = int(1000 / ltp_frequency)
        t += isi

    t = test_stimulus_2
    spikes.append(t)

    return spikes

# %%
def match_array_size(*arrays):
    min_len = min(arr.shape[0] for arr in arrays)
    return [arr[:min_len] for arr in arrays]

# %%
spikes = generate_ltp_spike_times()

# %%
idx = 1
# [0, 1, 2, 5, 6, 7]

voltage0_9 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_0.9_voltage.csv", index_col = 0)
weights0_9 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_0.9_weights.csv", index_col = 0)

voltage1 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_1_voltage.csv", index_col = 0)
weights1 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_1_weights.csv", index_col = 0)

voltage1_1 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_1.1_voltage.csv", index_col = 0)
weights1_1 = pd.read_csv(f"output/temporal-interference-1/figures/figure2/{idx}_1.1_weights.csv", index_col = 0)

voltage5 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_5_0.9_0.1/voltage.csv", index_col = 0)
weights5 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_5_0.9_0.1/synapse_weights.csv", index_col = 0)

voltage130 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_130_0.9_0.1/voltage.csv")
weights130 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_130_0.9_0.1/synapse_weights.csv", index_col = 0)

voltage0 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_0_0.32_0.1/voltage.csv")
weights0 = pd.read_csv(f"output/temporal-interference-1/{idx}/subthreshold_conductance/ltp/1000_0_0.32_0.1/synapse_weights.csv")

with open(f"output/temporal-interference-1/{idx}/subthreshold_conductance.txt", "r") as file:
    conductance = float(file.read())

# %%
fig = plt.figure(figsize = (8.4, 6.5))

outer_gs = gridspec.GridSpec(3, 1, height_ratios = [1, 0.21, 1])

# --- A and B panels ---
inner_gs = gridspec.GridSpecFromSubplotSpec(4, 4, subplot_spec = outer_gs[0], width_ratios = [1, 1, 0.1, 1], height_ratios = [0.7, 1, 1, 1])
ax_a1 = fig.add_subplot(inner_gs[0, 0:2])

ax = ax_a1

ax.axvspan(
    test_stimulus_1 + 10,
    test_stimulus_1 + 35,
    alpha = 0.2,
    color = "tab:red",
    label = "Test stimulus",
    zorder = 1,
    linewidth = 0
)

ax.axvspan(
    test_stimulus_2 - 10,
    test_stimulus_2 + 15,
    alpha = 0.2,
    color = "tab:red",
    zorder = 1,
    linewidth = 0
)

ax.axvspan(
    ltp_start - 10,
    ltp_start + ltp_duration + 20,
    alpha = 0.2,
    color = "tab:orange",
    label = "LTP induction",
    zorder = 1,
    linewidth = 0
)

ax.eventplot(
    spikes,
    lineoffsets = 1,
    linelengths = 1.25,
    colors = "black",
    linewidths = 0.75,
    zorder = 3,
    rasterized = True
)

for spine in ["top", "right", "left"]:
    ax.spines[spine].set_visible(False)

ax.set_ylim(-0.5, 2.5)

ax.set_xlabel("Time, ms")
ax.set_xlim(-50, 3050)
ax.set_xticks(np.arange(0, 3200, 500))
ax.tick_params(left = False, labelleft = False)

ax.legend(loc = "upper center", bbox_to_anchor = (0.5, 2), frameon = False, ncol = 2)

ax.set_title("LTP protocol for each synapse", y = 1.7, fontsize = 10)

# --- C panel ---

voltage = voltage1
time_before = 50
time_after = 100

ax_a2 = fig.add_subplot(inner_gs[0:4, 3])

ax = ax_a2

time_epsp_before = np.logical_and(voltage.Time > test_stimulus_1 - time_before, voltage.Time < test_stimulus_1 + time_after)
epsp_before = np.array(voltage.Voltage[time_epsp_before].tolist())

time_epsp_after = np.logical_and(voltage.Time > test_stimulus_2 - time_before, voltage.Time < test_stimulus_2 + time_after)
epsp_after = np.array(voltage.Voltage[time_epsp_after].tolist())

time = np.array((voltage.Time[time_epsp_before] - test_stimulus_1).tolist())
time, epsp_before, epsp_after = match_array_size(time, epsp_before, epsp_after)

ax.plot(
    time,
    epsp_before,
    color = "tab:blue",
    label = "Before LTP",
    linewidth = 1
)

ax.axvspan(
    -1,
    1,
    alpha = 0.2,
    color = "tab:red",
    zorder = 1,
    linewidth = 0
)

ax.plot(
    time,
    epsp_after,
    color = "tab:orange",
    label = "After LTP",
    linewidth = 1
)

ax.set_ylim(-67.5, -56.5)
ax.set_yticks(np.arange(-66, -56, 2))
ax.grid(alpha = 0.25)

ax.legend(frameon = False, loc = "upper center", bbox_to_anchor = (0.5, 1.1725), ncol = 2)

ax.set_ylabel("Voltage, mV")
ax.set_xlabel("Time, ms")

ax.set_title("EPSP", y = 1.11, fontsize = 10)

# --- D panel ---

inner_gs = gridspec.GridSpecFromSubplotSpec(2, 3, subplot_spec = outer_gs[2], width_ratios = [1, 1, 1])
axs = np.array([
    [ fig.add_subplot(inner_gs[0, 0]), fig.add_subplot(inner_gs[0, 1]), fig.add_subplot(inner_gs[0, 2]) ],
    [ fig.add_subplot(inner_gs[1, 0]), fig.add_subplot(inner_gs[1, 1]), fig.add_subplot(inner_gs[1, 2]) ]
])

for ax, voltage in zip(axs[0], [voltage0_9, voltage1, voltage1_1]):
    ax.axvspan(
        test_stimulus_1 - 25,
        test_stimulus_1 + 25,
        alpha = 0.2,
        color = "tab:red",
        label = "Test stimulus",
        zorder = 1,
        linewidth = 0
    )

    ax.axvspan(
        test_stimulus_2 - 25,
        test_stimulus_2 + 25,
        alpha = 0.2,
        color = "tab:red",
        zorder = 1,
        linewidth = 0
    )

    ax.axvspan(
        ltp_start - 5,
        ltp_start + ltp_duration + 5,
        alpha = 0.2,
        color = "tab:orange",
        label = "LTP induction",
        zorder = 1,
        linewidth = 0
    )

    ax.plot(
        voltage.Time,
        voltage.Voltage,
        color = "black",
        linewidth = 0.5,
        zorder = 3
    )

    ax.tick_params(bottom = False, labelbottom = False)
    ax.set_ylim(-90, 70)
    ax.set_yticks(np.arange(-50, 100, 50))
    ax.tick_params(left = False, labelleft = False)
    ax.set_xlim(-50, 3050)

    ax.grid(True, alpha = 0.25, axis = "y")

axs[0][0].set_ylabel("Voltage, mV")
axs[0][0].tick_params(left = True, labelleft = True)

for ax, weights in zip(axs[1], [weights0_9, weights1, weights1_1]):
    ax.set_xlabel("Time, ms")
    ax.set_xlim(-50, 3050)

    ax.axvspan(
        test_stimulus_1 - 25,
        test_stimulus_1 + 25,
        alpha = 0.2,
        color = "tab:red",
        label = "Test stimulus",
        zorder = 1,
        linewidth = 0
    )

    ax.axvspan(
        test_stimulus_2 - 25,
        test_stimulus_2 + 25,
        alpha = 0.2,
        color = "tab:red",
        zorder = 1,
        linewidth = 0
    )

    ax.axvspan(
        ltp_start - 5,
        ltp_start + ltp_duration + 5,
        alpha = 0.2,
        color = "tab:orange",
        label = "LTP induction",
        zorder = 1,
        linewidth = 0
    )

    for synapse in [f"Synapse{i}" for i in range(10)]:
        ax.plot(
            weights.Time,
            weights[synapse],
            linewidth = 0.5,
            color = "black",
        )

    ax.tick_params(left = False, labelleft = False)
    ax.set_ylim(-0.1, 1.1)
    
    ax.grid(True, alpha = 0.25, axis = "y")

axs[1][0].tick_params(left = True, labelleft = True)
axs[1][0].set_ylabel("Synaptic weight")

axs[0][0].set_title(f"{round(conductance * 1000_000 * 0.9)} pS\n90% subthreshold conductance", fontsize = 10)
axs[0][1].set_title(f"{round(conductance * 1000_000)} pS\n100% subthreshold conductance", fontsize = 10)
axs[0][2].set_title(f"{round(conductance * 1000_000 * 1.1)} pS\n110% subthreshold conductance", fontsize = 10)

fig.align_ylabels(axs)

fig.align_ylabels(axs)

fig.text(0.04, 0.915, "A", fontsize = 12)
fig.text(0.04, 0.72, "B", fontsize = 12)
fig.text(0.61, 0.915, "C", fontsize = 12)
fig.text(0.04, 0.47, "D", fontsize = 12)
# fig.text(0.04, 0.318, "E", fontsize = 12)

plt.savefig("cns_2025_figure2.png", dpi = 500, bbox_inches = "tight")
