# %% [markdown]
# # Figure 1
#
# Methodical figure - look for examples on how to make this informative and useful
#
# - Neuron model with electric field and synapses
# - TI conditions explored
# - CA1 model, CA3 inputs
# - Synaptic inputs
# - 20 simulations, 10 synaptic locations randomised
# - TI waveform and modelling
# - Synaptic conductance estimation
# - Subthreshold field strength
# - Parameters used in other simulations (?)
#
# # Figure 2
#
# TI modulates plasticity under low-frequency Poisson synaptic input
#
# - Remind the reader about the experimental setup in this case
# - Synaptic weight dynamics
# - Final synaptic weights
# - Kolmogorov-Smirnov statistic for different Poisson frequencies
#
# # Figure 3
#
# TI modulates plasticity under in-vivo-like inputs
#
# - Experimental setup overview in this case as well
# - Example somatic voltage traces
# - Exponential rise fit parameters
# - Synaptic weight dynamics
# - Final synaptic weights
#
# # Figure 4 (later, now focus on 1-3)
#
# Synaptic weight dynamics under different parameter setup: show that the model predicts consistent results with different parameter combinations.
#
# - Pick one to three Poisson frequencies to perform the simulations
# - Varying strength of the electric fields (0.8, 0.7 for 1000 Hz carrier)
# - Varying orientation of the electric fields (parallel vs perpendicular) - would the results really be different here?
# - Varying carrier frequency (0.9 field strength, 1000-9000 Hz carriers)
