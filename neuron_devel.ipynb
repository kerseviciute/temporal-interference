# %%
from plastic_neuron import PlasticNeuron
from neuron import h

# %%
neuron = PlasticNeuron()
# Out:
# Creating cell
# Inserting 10 synapses

# %%
neuron.synapse_info
# Out:
#    Dendrite  Location    Distance      Delay
# 0        14  0.139538  116.315870  10.249518
# 0         5  0.590493  184.839315   3.178268
# 0         5  0.218638  125.874136  50.535529
# 0        28  0.589266  287.073876  80.943046
# 0        21  0.277871  179.285582  21.531376
# 0         5  0.379927  149.460208  35.897938
# 0        22  0.603726  160.043804  80.712827
# 0         7  0.973116  210.756824  37.853438
# 0        23  0.577352  255.118383  70.457184
# 0         2  0.661263  184.257752  77.306834
